# %% [markdown]
# ## XGBoost
#
# http://datascience.stackexchange.com/questions/9364/hypertuning-xgboost-parameters
#
# # Owen Zhang [#1](http://www.slideshare.net/odsc/owen-zhangopen-sourcetoolsanddscompetitions1)
# - target around 100 trees, find best learning rate
# - max depth - start with 6, tune
# - min_child_weight - start with 1 / sqrt(event rate)
# - colsample_bytree - .3 - .5
# - subsampling - leave at 1
# - gamma - usually ok at 0
#
# Example learning curves to look for in tuning:

# %%
from IPython.display import Image
Image(filename='images/xgboost_tuning_learning_curves.png')
